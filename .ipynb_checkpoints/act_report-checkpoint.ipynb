# %% [markdown]
# *Hi everyone, i am most excited to share with you the insights and visualizations produced from my wrangled data. I mean, its beautiful turning raw data from nothing to something one could actually present.  Well, without further ado let me get to the presentation*

# %% [markdown]
# ## @WeRateDogs official twitter page

# %% [markdown]
# ![WeRateDogs%C2%AE%20%28@dog_rates%29%20_%20Twitter%20-%20Google%20Chrome%207_1_2022%2012_09_10%20AM%20(2).png](attachment:WeRateDogs%C2%AE%20%28@dog_rates%29%20_%20Twitter%20-%20Google%20Chrome%207_1_2022%2012_09_10%20AM%20(2).png)

# %% [markdown]
# <br>

# %% [markdown]
# *A quick background of my wrangled data: This data was provided by <a href = "https://udacity.com/">Udacity</a> for my second project in the Data Analytics Nanodegree Program i am currently enrrolled in. I have wrangled my data and i outline the steps to do that <a href = "link to my github repo">here</a>. I have highlighted below the insights gotten from the analysis of this wrangled data. Also, i made amazing visualizations to better communicate my findings from the data.*

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# *`.describe()`, `.isnull()` e.t.c among many other methods used in pandas to perform exploratory data analysis was also applied to the wrangled data. I was able to get statistical facts about my data. Some of these facts include:*
# - the average rating for each dog is 10.8
# - The maximum retweet count for a tweet_id is a wholesome 70839 while the maximum favourite count for a dog tweet id is about 145k
# - the average confidence level of prediction algorithm 1 is the highest of all prediction algorithms with 0.60

# %% [markdown]
# This is an image of the `.describe()` method in action
#
# ![wrangle_act%20-%20Jupyter%20Notebook%20-%20Google%20Chrome%206_26_2022%2011_06_28%20PM.png](attachment:wrangle_act%20-%20Jupyter%20Notebook%20-%20Google%20Chrome%206_26_2022%2011_06_28%20PM.png)

# %% [markdown]
# ## Data Visualizations

# %% [markdown]
# *Visualizations are best used to effectively communicate answers to questions posed for data analysis. I posed two questions and attempted to communicate the answer vissually. Now check these question out;*

# %% [markdown]
# ### Is there a correlation between the favorite count and retweet count?

# %% [markdown]
# `df_master.corr(method = 'pearson')`

# %% [markdown]
# The above code in action:
#
# ![wrangle_act%20-%20Jupyter%20Notebook%20-%20Google%20Chrome%206_26_2022%2011_14_06%20PM.png](attachment:wrangle_act%20-%20Jupyter%20Notebook%20-%20Google%20Chrome%206_26_2022%2011_14_06%20PM.png)

# %% [markdown]
# - the snapshot would have done a good job in answering the question but how about this?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *You see that?the colours did an amazing job passing the information accross!*
#
# *Now lets check out the other question posed*

# %% [markdown]
# ## Comparing the performance of algorithm's predictions(p1,p2 and p3). How did each fair?

# %% [markdown]
# *Given that the image of each dog was ran through a neural network to predict if the image is a dog or not and also to return the confidence of each prediction and its percieved breed*
#
# *here, i analysed and compare the three predictions and how they differ. Firstly, i defined a function to plot dog breeds where the number of dog breeds predicted has more than 20 occurences for each predition ,that is, where the prediction is truly a dog*
#
# *below are the results of this analysis, where i was able to know how each prediction faired*

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# *You will quickly notice the difference in the number of dog breeds in each visuals*. *Now, thats how the prediction faired. The 3rd predictions have lower level of confidence compared to the first and second one*

# %% [markdown]
# *i also wrote a code to detect some information about the breeds present in the visualizations above* check them out👇👇

# %% [markdown]
# ![wrangle_act%20-%20Jupyter%20Notebook%20-%20Google%20Chrome%206_26_2022%2011_48_34%20PM%20%282%29.png](attachment:wrangle_act%20-%20Jupyter%20Notebook%20-%20Google%20Chrome%206_26_2022%2011_48_34%20PM%20%282%29.png)

# %% [markdown]
# *Yeah, so i hope y'all get the gist. visualizations are amazing and can go a long way to tell the data's story. Peace!!*
